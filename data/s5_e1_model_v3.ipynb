# %%
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt 
import numpy as np
import optuna
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import holidays 

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_absolute_percentage_error, mean_absolute_error, mean_squared_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

import category_encoders as ce
import xgboost as xgb
from xgboost import XGBRegressor
from ydata_profiling import ProfileReport
from sklearn.linear_model import LinearRegression

import catboost as cb
from scalecast.Forecaster import Forecaster

import lightgbm as lgb
import torch

import time

alt.data_transformers.disable_max_rows()
sklearn.set_config(transform_output="pandas")

# %% [markdown]
# ## Import Data

# %%
train = pd.read_csv('train.csv')
blind = pd.read_csv('test.csv')

# %%
def is_holiday(row):
    """
    Determines if a given date is a holiday in the specified country.
    Optimized for Canada, Finland, and Italy.
    
    Parameters:
    row: pandas Series containing 'country' and 'date' columns
    
    Returns:
    bool: True if the date is a holiday in the given country, False otherwise
    """
    country = row['country']
    date = pd.to_datetime(row['date']).date()  # Convert to date only

    country_mapping = {
        'Canada': holidays.CA(),
        'Finland': holidays.FI(),
        'Italy': holidays.IT(), 
        'Kenya': holidays.KE(),
        'Norway': holidays.NO(),
        'Singapore': holidays.SG(),
    }
    
    try:
        # Get the holidays object for the country
        if country in country_mapping:
            country_holidays = country_mapping[country]
            return date in country_holidays
        else:
            return False
    except Exception as e:
        print(f"Error checking holiday for {country} on {date}: {e}")
        return False

# Create a cache of holiday objects to improve performance
def initialize_holiday_detection(df):
    """
    Initialize holiday detection by creating holiday objects for all unique years in the dataset.
    This improves performance by avoiding repeated creation of holiday objects.
    
    Parameters:
    df: pandas DataFrame containing 'date' column
    """
    years = pd.to_datetime(df['date']).dt.year.unique()
    holiday_cache = {
        'Canada': {year: holidays.CA(years=year) for year in years},
        'Finland': {year: holidays.FI(years=year) for year in years},
        'Italy': {year: holidays.IT(years=year) for year in years}, 
        'Kenya': {year: holidays.KE(years=year) for year in years},
        'Norway': {year: holidays.NO(years=year) for year in years},
        'Singapore': {year: holidays.SG(years=year) for year in years}

    }
    
    def is_holiday_cached(row):
        country = row['country']
        date = pd.to_datetime(row['date']).date()
        year = date.year
        
        try:
            if country in holiday_cache:
                return date in holiday_cache[country][year]
            return False
        except Exception as e:
            print(f"Error checking holiday for {country} on {date}: {e}")
            return False
    
    return is_holiday_cached

# Example usage:
# First initialize the cached version
holiday_checker = initialize_holiday_detection(train)

# Then apply it to create the holiday flag
train['is_holiday'] = train.apply(holiday_checker, axis=1)

holiday_checker = initialize_holiday_detection(blind)
blind['is_holiday'] = blind.apply(holiday_checker, axis=1)

# %%
def feature_eng(df):
    df = df.copy()
    try: 
        df['date'] = pd.to_datetime(df['date'])
        df['day_of_year'] = df['date'].dt.dayofyear
        df['month'] = df['date'].dt.month
        df['year'] = df['date'].dt.year
    except: pass

    df[["country", "store", "product", "is_holiday"]] = df[["country", "store", "product", "is_holiday"]].astype("category")

    # Encode categorical features
    # Drop missing values and irrelevant columns
    imputer = SimpleImputer(strategy="mean")  # Change to "mean", "most_frequent", or "constant"
    scaler = MinMaxScaler()
    try: 
        df = df.set_index('id')

        df = df.drop(columns=['date'])  # Dropping columns that are not useful for modeling
    except: pass
    # Separate features and target
    try: 
        df["num_sold"] = imputer.fit_transform(df[["num_sold"]])
       # df["num_sold"] = scaler.fit_transform(df[["num_sold"]])
    except: pass
    
    try: 
        X = df.drop(columns=['num_sold'])
        #X = pd.get_dummies(X)
    except:
        X=df#pd.get_dummies(df)
    try:
        y = df['num_sold']
    except:
        y = None
    # Scale features
    return df, X, y

# Feature engineering
df, X, y = feature_eng(train)
blind = feature_eng(blind)[1]

# Splitting the data
SPLIT = 0.85
split_index = int(SPLIT * len(X))

X_train = X[:split_index]
y_train = y[:split_index]
X_test = X[split_index:]
y_test = y[split_index:]

# Verify shapes
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (195610, 7)
# y_train shape: (195610,)
# X_test shape: (34520, 7)
# y_test shape: (34520,)

# %%
import time

def objective(trial, X_train, X_test, y_train, y_test, total_trials):
    """
    Optuna objective function for XGBoost hyperparameter optimization with GPU support.
    """
    trial_start = time.time()
    print(f"🔄 Starting Trial {trial.number + 1} out of {total_trials}")
    
    gpu_available = torch.cuda.is_available()
    device = "gpu" if gpu_available else "cpu"
    tree_method = "hist" if gpu_available else "auto"
    
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 18),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.1, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.1, 10.0, log=True),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 7),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "enable_categorical": True,
        "device": device,
        "tree_method": tree_method
    }
    
    try:
        if device == "gpu":
            X_train_device = xgb.DMatrix(X_train, y_train)
            X_test_device = xgb.DMatrix(X_test)
        else:
            X_train_device = X_train
            X_test_device = X_test
        
        model = xgb.XGBRegressor(
            **param,
            early_stopping_rounds=50,
            eval_metric=['mae', 'mape']
        )
        
        model.fit(
            X_train_device, y_train,
            eval_set=[(X_test_device, y_test)],
            verbose=False
        )
        
        preds = model.predict(X_test_device)
        mape = mean_absolute_percentage_error(y_test, preds)
        mae = np.mean(np.abs(y_test - preds))
        rmse = np.sqrt(np.mean((y_test - preds) ** 2))
        
        trial.set_user_attr('mae', mae)
        trial.set_user_attr('rmse', rmse)
        trial.set_user_attr('n_estimators_used', model.best_iteration or param['n_estimators'])
        
        trial_time = time.time() - trial_start
        print(f"✅ Trial {trial.number + 1} completed in {trial_time:.1f}s")
        print(f"   MAPE: {mape:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")
        
        return mape
        
    except Exception as e:
        print(f"❌ Trial {trial.number + 1} failed: {str(e)}")
        raise optuna.exceptions.TrialPruned()

def run_optimization(X_train, X_test, y_train, y_test, n_trials=2):
    """
    Run the complete optimization process and return the best model.
    """
    study = optuna.create_study(direction="minimize")
    
    try:
        study.optimize(
            lambda trial: objective(trial, X_train, X_test, y_train, y_test, n_trials),
            n_trials=n_trials,
            show_progress_bar=True
        )
        
        best_params = study.best_params
        best_params.update({
            "enable_categorical": True,
            "device": "gpu" if torch.cuda.is_available() else "cpu",
            "tree_method": "hist" if torch.cuda.is_available() else "auto"
        })
        
        best_model = xgb.XGBRegressor(**best_params)
        best_model.fit(X_train, y_train)
        
        print("\n🏆 Best Trial Results:")
        print(f"MAPE: {study.best_value:.4f}")
        print("Best Parameters:", best_params)
        
        return best_model, study
        
    except KeyboardInterrupt:
        print("\n⚠️ Optimization interrupted by user")
        return None, study

def train_country_models(df, X_train, X_test, y_train, y_test, n_trials=2):
    """
    Train separate XGBoost models for each country using Optuna optimization.
    """
    start_time = time.time()
    countries = df['country'].unique()
    country_models = {}
    
    for country in countries:
        country_start_time = time.time()
        print(f"\n🌍 Training model for {country}")
        print("=" * 50)
        
        train_country_mask = df.loc[X_train.index]['country'] == country
        test_country_mask = df.loc[X_test.index]['country'] == country
        
        X_train_country = X_train[train_country_mask]
        X_test_country = X_test[test_country_mask]
        y_train_country = y_train[train_country_mask]
        y_test_country = y_test[test_country_mask]
        
        if len(X_train_country) < 10:
            print(f"⚠️ Insufficient data for {country}. Skipping...")
            continue
            
        try:
            best_model, study = run_optimization(
                X_train_country, 
                X_test_country,
                y_train_country, 
                y_test_country,
                n_trials=n_trials
            )
            
            if best_model is not None:
                predictions = best_model.predict(X_test_country)
                final_mape = mean_absolute_percentage_error(y_test_country, predictions)
                
                country_models[country] = {
                    'model': best_model,
                    'study': study,
                    'mape': final_mape,
                    'n_train_samples': len(X_train_country),
                    'n_test_samples': len(X_test_country),
                    'best_parameters': study.best_params,
                    'training_time': time.time() - country_start_time
                }
                
                print(f"\n📊 Results for {country}:")
                print(f"Training samples: {len(X_train_country)}")
                print(f"Test samples: {len(X_test_country)}")
                print(f"Final MAPE: {final_mape:.4f}")
                print(f"Training time: {country_models[country]['training_time']:.1f}s")
                
        except Exception as e:
            print(f"❌ Error training model for {country}: {str(e)}")
            continue
    
    total_time = time.time() - start_time
    print(f"\n⏱️ Total training time: {total_time:.1f}s")
    
    print("\n📑 Overall Summary:")
    print("=" * 50)
    summary_data = []
    for country, results in country_models.items():
        summary_data.append({
            'Country': country,
            'MAPE': results['mape'],
            'Training Samples': results['n_train_samples'],
            'Test Samples': results['n_test_samples'],
            'Training Time (s)': results['training_time']
        })
    
    summary_df = pd.DataFrame(summary_data)
    print(summary_df)
    
    return country_models

def predict_with_country_models(X_new, country_models, country_column):
    """
    Make predictions using country-specific models on new, unlabeled data.
    
    Parameters:
    X_new: DataFrame containing features for prediction (without target)
    country_models: Dictionary of trained models from train_country_models()
    country_column: String or array containing country values for each row
    
    Returns:
    array: Predictions for each row
    """
    predictions = np.zeros(len(X_new))
    
    for country, model_dict in country_models.items():
        # Get indices for this country
        country_mask = country_column == country
        
        if country_mask.any():
            # Get predictions for this country
            country_data = X_new[country_mask]
            predictions[country_mask] = model_dict['model'].predict(country_data)
    
    return predictions

# Example usage:

# Train the models
country_models = train_country_models(
    df=train,
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    n_trials=20
)

# Make predictions
predictions = predict_with_country_models(
    blind, 
    country_models, 
    blind['country'])
# Out:
# [I 2025-01-30 16:34:32,854] A new study created in memory with name: no-name-ce08c678-0768-4f1a-93d4-76e988aed254
# 🌍 Training model for Canada
# ==================================================
#   0%|          | 0/20 [00:00<?, ?it/s]
# 🔄 Starting Trial 1 out of 20
# ✅ Trial 1 completed in 0.4s
#    MAPE: 0.1480, MAE: 91.3790, RMSE: 124.9555
# [I 2025-01-30 16:34:33,324] Trial 0 finished with value: 0.148006009725715 and parameters: {'n_estimators': 89, 'learning_rate': 0.11004005019811143, 'max_depth': 6, 'subsample': 0.8825560098780566, 'colsample_bytree': 0.6298945689472297, 'reg_alpha': 4.222504380990488, 'reg_lambda': 0.7813791824154713, 'min_child_weight': 3, 'gamma': 0.17091598545284414}. Best is trial 0 with value: 0.148006009725715.
# 🔄 Starting Trial 2 out of 20
# ✅ Trial 2 completed in 1.0s
#    MAPE: 0.1958, MAE: 105.0906, RMSE: 130.7108
# [I 2025-01-30 16:34:34,292] Trial 1 finished with value: 0.1958252808730472 and parameters: {'n_estimators': 413, 'learning_rate': 0.010032680748256856, 'max_depth': 6, 'subsample': 0.5916275003461888, 'colsample_bytree': 0.7076861888821623, 'reg_alpha': 0.4622464534607482, 'reg_lambda': 0.1811274379543044, 'min_child_weight': 4, 'gamma': 2.3822884395077235}. Best is trial 0 with value: 0.148006009725715.
# 🔄 Starting Trial 3 out of 20
# ✅ Trial 3 completed in 0.6s
#    MAPE: 0.1324, MAE: 85.4365, RMSE: 124.9965
# [I 2025-01-30 16:34:34,888] Trial 2 finished with value: 0.1323629449132864 and parameters: {'n_estimators': 138, 'learning_rate': 0.056853986458814794, 'max_depth': 9, 'subsample': 0.9426079912123896, 'colsample_bytree': 0.9241266950790601, 'reg_alpha': 1.1846377174806788, 'reg_lambda': 0.12288674923240042, 'min_child_weight': 1, 'gamma': 0.1360142044432583}. Best is trial 2 with value: 0.1323629449132864.
# 🔄 Starting Trial 4 out of 20
# ✅ Trial 4 completed in 0.9s
#    MAPE: 0.1324, MAE: 84.8329, RMSE: 124.6314
# [I 2025-01-30 16:34:35,838] Trial 3 finished with value: 0.13239081353907756 and parameters: {'n_estimators': 191, 'learning_rate': 0.10156918073414663, 'max_depth': 14, 'subsample': 0.7051953288876114, 'colsample_bytree': 0.8726598925611305, 'reg_alpha': 6.551300601674001, 'reg_lambda': 3.7146348589090437, 'min_child_weight': 7, 'gamma': 4.729359130998535}. Best is trial 2 with value: 0.1323629449132864.
# 🔄 Starting Trial 5 out of 20
# ✅ Trial 5 completed in 2.3s
#    MAPE: 0.1305, MAE: 85.5320, RMSE: 133.2481
# [I 2025-01-30 16:34:38,124] Trial 4 finished with value: 0.13051772229682 and parameters: {'n_estimators': 322, 'learning_rate': 0.13049746494117537, 'max_depth': 18, 'subsample': 0.5259452529969817, 'colsample_bytree': 0.9074511241447343, 'reg_alpha': 7.910736084303757, 'reg_lambda': 0.28061641573250684, 'min_child_weight': 1, 'gamma': 3.7109175874754214}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 6 out of 20
# ✅ Trial 6 completed in 0.5s
#    MAPE: 0.1575, MAE: 91.1847, RMSE: 122.5109
# [I 2025-01-30 16:34:38,640] Trial 5 finished with value: 0.15745939103562273 and parameters: {'n_estimators': 143, 'learning_rate': 0.023237261977128727, 'max_depth': 7, 'subsample': 0.9809223212879986, 'colsample_bytree': 0.8859512928440203, 'reg_alpha': 0.3740877827114873, 'reg_lambda': 1.4848537580174832, 'min_child_weight': 5, 'gamma': 0.4203091586996116}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 7 out of 20
# ✅ Trial 7 completed in 0.9s
#    MAPE: 0.1337, MAE: 85.5286, RMSE: 123.6954
# [I 2025-01-30 16:34:39,505] Trial 6 finished with value: 0.13367361650813517 and parameters: {'n_estimators': 261, 'learning_rate': 0.02973110286055058, 'max_depth': 8, 'subsample': 0.6954627723850786, 'colsample_bytree': 0.9014265284898011, 'reg_alpha': 0.3070268238627381, 'reg_lambda': 0.3413854952047101, 'min_child_weight': 3, 'gamma': 4.816433335698177}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 8 out of 20
# ✅ Trial 8 completed in 1.1s
#    MAPE: 0.1341, MAE: 85.4920, RMSE: 123.5429
# [I 2025-01-30 16:34:40,640] Trial 7 finished with value: 0.13407231219863544 and parameters: {'n_estimators': 310, 'learning_rate': 0.054172483401535694, 'max_depth': 12, 'subsample': 0.8874104742049344, 'colsample_bytree': 0.8203704262222942, 'reg_alpha': 1.2460279488251966, 'reg_lambda': 9.480049177593738, 'min_child_weight': 3, 'gamma': 1.4965669087170397}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 9 out of 20
# ✅ Trial 9 completed in 0.7s
#    MAPE: 0.1409, MAE: 89.5261, RMSE: 125.6395
# [I 2025-01-30 16:34:41,342] Trial 8 finished with value: 0.14092790421918905 and parameters: {'n_estimators': 398, 'learning_rate': 0.1007007743495889, 'max_depth': 9, 'subsample': 0.5108455420662773, 'colsample_bytree': 0.6734898260943831, 'reg_alpha': 5.5887492569447215, 'reg_lambda': 0.11043891699274962, 'min_child_weight': 2, 'gamma': 0.46065989086512993}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 10 out of 20
# ✅ Trial 10 completed in 0.5s
#    MAPE: 0.2549, MAE: 117.9199, RMSE: 151.8814
# [I 2025-01-30 16:34:41,906] Trial 9 finished with value: 0.25485056208182166 and parameters: {'n_estimators': 125, 'learning_rate': 0.011290363511276819, 'max_depth': 12, 'subsample': 0.8401128952405786, 'colsample_bytree': 0.8853345545623859, 'reg_alpha': 1.9702198084077325, 'reg_lambda': 8.49193460435343, 'min_child_weight': 2, 'gamma': 2.137809516839882}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 11 out of 20
# ✅ Trial 11 completed in 1.1s
#    MAPE: 0.1488, MAE: 93.4488, RMSE: 130.4874
# [I 2025-01-30 16:34:43,025] Trial 10 finished with value: 0.1487614094440228 and parameters: {'n_estimators': 495, 'learning_rate': 0.19760073022136937, 'max_depth': 18, 'subsample': 0.5054463836500843, 'colsample_bytree': 0.5695726379442885, 'reg_alpha': 9.808766741433544, 'reg_lambda': 0.45372420607633385, 'min_child_weight': 6, 'gamma': 3.5471763597153934}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 12 out of 20
# ✅ Trial 12 completed in 0.6s
#    MAPE: 0.1632, MAE: 98.9978, RMSE: 130.1591
# [I 2025-01-30 16:34:43,640] Trial 11 finished with value: 0.1631624956711972 and parameters: {'n_estimators': 272, 'learning_rate': 0.05026893895527054, 'max_depth': 3, 'subsample': 0.9934039971585823, 'colsample_bytree': 0.9940058082705011, 'reg_alpha': 2.5985450030125823, 'reg_lambda': 0.10180969761609743, 'min_child_weight': 1, 'gamma': 3.3209986973659995}. Best is trial 4 with value: 0.13051772229682.
# 🔄 Starting Trial 13 out of 20
# ✅ Trial 13 completed in 2.7s
#    MAPE: 0.1301, MAE: 85.1583, RMSE: 133.5255
# [I 2025-01-30 16:34:46,307] Trial 12 finished with value: 0.13007751516337557 and parameters: {'n_estimators': 215, 'learning_rate': 0.19372724935923935, 'max_depth': 18, 'subsample': 0.7921829667333617, 'colsample_bytree': 0.9865542794838948, 'reg_alpha': 0.1243915541536559, 'reg_lambda': 0.22464149928283908, 'min_child_weight': 1, 'gamma': 3.643192444587748}. Best is trial 12 with value: 0.13007751516337557.
# 🔄 Starting Trial 14 out of 20
# ✅ Trial 14 completed in 2.7s
#    MAPE: 0.1303, MAE: 85.3690, RMSE: 133.3532
# [I 2025-01-30 16:34:49,036] Trial 13 finished with value: 0.1303119843320645 and parameters: {'n_estimators': 337, 'learning_rate': 0.18442503890436623, 'max_depth': 18, 'subsample': 0.7882548206149765, 'colsample_bytree': 0.9822102102550673, 'reg_alpha': 0.14542292152761535, 'reg_lambda': 0.32715669802923164, 'min_child_weight': 1, 'gamma': 3.474623688125153}. Best is trial 12 with value: 0.13007751516337557.
# 🔄 Starting Trial 15 out of 20
# ✅ Trial 15 completed in 1.1s
#    MAPE: 0.1288, MAE: 84.1970, RMSE: 126.7058
# [I 2025-01-30 16:34:50,173] Trial 14 finished with value: 0.12884348093447442 and parameters: {'n_estimators': 199, 'learning_rate': 0.19925144741463305, 'max_depth': 15, 'subsample': 0.7796923094040221, 'colsample_bytree': 0.9844347586090221, 'reg_alpha': 0.1096781616965365, 'reg_lambda': 1.1262048708328567, 'min_child_weight': 2, 'gamma': 4.1264740724932345}. Best is trial 14 with value: 0.12884348093447442.
# 🔄 Starting Trial 16 out of 20
# ✅ Trial 16 completed in 1.4s
#    MAPE: 0.1332, MAE: 85.5459, RMSE: 124.6031
# [I 2025-01-30 16:34:51,554] Trial 15 finished with value: 0.13315469135063826 and parameters: {'n_estimators': 211, 'learning_rate': 0.07536950329829212, 'max_depth': 15, 'subsample': 0.7608073888134025, 'colsample_bytree': 0.7674040856513785, 'reg_alpha': 0.1005957178700573, 'reg_lambda': 1.5099469682456537, 'min_child_weight': 2, 'gamma': 4.140006373656155}. Best is trial 14 with value: 0.12884348093447442.
# 🔄 Starting Trial 17 out of 20
# ✅ Trial 17 completed in 0.3s
#    MAPE: 0.2219, MAE: 118.8660, RMSE: 149.6014
# [I 2025-01-30 16:34:51,831] Trial 16 finished with value: 0.22193392464928527 and parameters: {'n_estimators': 55, 'learning_rate': 0.1449950974973938, 'max_depth': 15, 'subsample': 0.6569766961359278, 'colsample_bytree': 0.5023042985042417, 'reg_alpha': 0.20493700161717435, 'reg_lambda': 0.8282501524487154, 'min_child_weight': 4, 'gamma': 2.9169767470307395}. Best is trial 14 with value: 0.12884348093447442.
# 🔄 Starting Trial 18 out of 20
# ✅ Trial 18 completed in 1.7s
#    MAPE: 0.1376, MAE: 85.8190, RMSE: 122.1410
# [I 2025-01-30 16:34:53,541] Trial 17 finished with value: 0.1376447927434405 and parameters: {'n_estimators': 214, 'learning_rate': 0.029516376693326483, 'max_depth': 16, 'subsample': 0.8113490015753748, 'colsample_bytree': 0.7967416818455525, 'reg_alpha': 0.668055131418234, 'reg_lambda': 2.1570799322461225, 'min_child_weight': 2, 'gamma': 3.997866855256484}. Best is trial 14 with value: 0.12884348093447442.
# 🔄 Starting Trial 19 out of 20
# ✅ Trial 19 completed in 1.2s
#    MAPE: 0.1311, MAE: 85.3905, RMSE: 128.7906
# [I 2025-01-30 16:34:54,741] Trial 18 finished with value: 0.13112976584760835 and parameters: {'n_estimators': 180, 'learning_rate': 0.15613717253399148, 'max_depth': 12, 'subsample': 0.7308074886920668, 'colsample_bytree': 0.9550425772464842, 'reg_alpha': 0.1006442663740998, 'reg_lambda': 0.6242250668948238, 'min_child_weight': 3, 'gamma': 4.559175738426739}. Best is trial 14 with value: 0.12884348093447442.
# 🔄 Starting Trial 20 out of 20
# ✅ Trial 20 completed in 1.4s
#    MAPE: 0.1337, MAE: 85.3430, RMSE: 123.2695
# [I 2025-01-30 16:34:56,156] Trial 19 finished with value: 0.13367240269740127 and parameters: {'n_estimators': 244, 'learning_rate': 0.0765488601755826, 'max_depth': 17, 'subsample': 0.8512885707999455, 'colsample_bytree': 0.8218503171077687, 'reg_alpha': 0.20916356988471965, 'reg_lambda': 3.8899373701769004, 'min_child_weight': 5, 'gamma': 2.827471844910425}. Best is trial 14 with value: 0.12884348093447442.
# [I 2025-01-30 16:34:58,958] A new study created in memory with name: no-name-7fd48d1e-5c8b-4c84-9bd7-170947d0a9e4
# 🏆 Best Trial Results:
# MAPE: 0.1288
# Best Parameters: {'n_estimators': 199, 'learning_rate': 0.19925144741463305, 'max_depth': 15, 'subsample': 0.7796923094040221, 'colsample_bytree': 0.9844347586090221, 'reg_alpha': 0.1096781616965365, 'reg_lambda': 1.1262048708328567, 'min_child_weight': 2, 'gamma': 4.1264740724932345, 'enable_categorical': True, 'device': 'cpu', 'tree_method': 'auto'}
#
# 📊 Results for Canada:
# Training samples: 32610
# Test samples: 5745
# Final MAPE: 0.1327
# Training time: 26.1s
#
# 🌍 Training model for Finland
# ==================================================
#   0%|          | 0/20 [00:00<?, ?it/s]
# 🔄 Starting Trial 1 out of 20
# ✅ Trial 1 completed in 0.9s
#    MAPE: 0.1201, MAE: 69.1807, RMSE: 98.8046
# [I 2025-01-30 16:34:59,875] Trial 0 finished with value: 0.12014569980305223 and parameters: {'n_estimators': 272, 'learning_rate': 0.012123798737494066, 'max_depth': 7, 'subsample': 0.8070877632803615, 'colsample_bytree': 0.9299792639514792, 'reg_alpha': 0.4657284633412854, 'reg_lambda': 1.2096407340003825, 'min_child_weight': 2, 'gamma': 1.2871133636064735}. Best is trial 0 with value: 0.12014569980305223.
# 🔄 Starting Trial 2 out of 20
# ✅ Trial 2 completed in 0.9s
#    MAPE: 0.0938, MAE: 66.1215, RMSE: 98.0266
# [I 2025-01-30 16:35:00,742] Trial 1 finished with value: 0.0938392470825015 and parameters: {'n_estimators': 164, 'learning_rate': 0.03798009654132587, 'max_depth': 15, 'subsample': 0.7042739083365632, 'colsample_bytree': 0.8332773556121789, 'reg_alpha': 0.9800262995709539, 'reg_lambda': 1.4518993073200224, 'min_child_weight': 7, 'gamma': 2.91018165402569}. Best is trial 1 with value: 0.0938392470825015.
# 🔄 Starting Trial 3 out of 20
# ✅ Trial 3 completed in 0.6s
#    MAPE: 0.1391, MAE: 72.6970, RMSE: 102.7953
# [I 2025-01-30 16:35:01,377] Trial 2 finished with value: 0.13913477107409275 and parameters: {'n_estimators': 124, 'learning_rate': 0.02273430687276883, 'max_depth': 11, 'subsample': 0.8661208887933152, 'colsample_bytree': 0.9332022610506455, 'reg_alpha': 0.2546428158914951, 'reg_lambda': 0.12632534386630773, 'min_child_weight': 6, 'gamma': 4.858261979535762}. Best is trial 1 with value: 0.0938392470825015.
# 🔄 Starting Trial 4 out of 20
# ✅ Trial 4 completed in 1.3s
#    MAPE: 0.0912, MAE: 65.2153, RMSE: 97.2068
# [I 2025-01-30 16:35:02,689] Trial 3 finished with value: 0.09117442031139121 and parameters: {'n_estimators': 489, 'learning_rate': 0.010328779611091318, 'max_depth': 7, 'subsample': 0.7202895771255635, 'colsample_bytree': 0.7847958991852113, 'reg_alpha': 6.706879792134475, 'reg_lambda': 3.7460349597675737, 'min_child_weight': 5, 'gamma': 4.332004687391327}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 5 out of 20
# ✅ Trial 5 completed in 0.4s
#    MAPE: 0.0915, MAE: 65.4684, RMSE: 96.9775
# [I 2025-01-30 16:35:03,088] Trial 4 finished with value: 0.09151025226109233 and parameters: {'n_estimators': 183, 'learning_rate': 0.13785580686104623, 'max_depth': 4, 'subsample': 0.5147315467718314, 'colsample_bytree': 0.8923003879086656, 'reg_alpha': 4.102901802082977, 'reg_lambda': 4.601611394737761, 'min_child_weight': 1, 'gamma': 1.084489709945418}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 6 out of 20
# ✅ Trial 6 completed in 0.8s
#    MAPE: 0.0958, MAE: 67.0429, RMSE: 98.9582
# [I 2025-01-30 16:35:03,859] Trial 5 finished with value: 0.09576579515983137 and parameters: {'n_estimators': 272, 'learning_rate': 0.05674344188694025, 'max_depth': 7, 'subsample': 0.9665716154754119, 'colsample_bytree': 0.6098432234231397, 'reg_alpha': 1.2413658459979693, 'reg_lambda': 0.14937269356691008, 'min_child_weight': 1, 'gamma': 4.26387387099805}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 7 out of 20
# ✅ Trial 7 completed in 2.2s
#    MAPE: 0.0947, MAE: 69.6715, RMSE: 105.0910
# [I 2025-01-30 16:35:06,041] Trial 6 finished with value: 0.09471380324025987 and parameters: {'n_estimators': 391, 'learning_rate': 0.05315511903104162, 'max_depth': 17, 'subsample': 0.9854608723213105, 'colsample_bytree': 0.9108076049476335, 'reg_alpha': 1.172793569739176, 'reg_lambda': 0.2696383911502271, 'min_child_weight': 1, 'gamma': 4.776130236141796}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 8 out of 20
# ✅ Trial 8 completed in 1.3s
#    MAPE: 0.0921, MAE: 68.2158, RMSE: 102.8067
# [I 2025-01-30 16:35:07,375] Trial 7 finished with value: 0.09206851621693449 and parameters: {'n_estimators': 210, 'learning_rate': 0.06892551897690398, 'max_depth': 17, 'subsample': 0.8802612501048435, 'colsample_bytree': 0.8938203146276114, 'reg_alpha': 0.22043658125704657, 'reg_lambda': 1.7576349641638946, 'min_child_weight': 4, 'gamma': 2.5164327176251695}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 9 out of 20
# ✅ Trial 9 completed in 0.1s
#    MAPE: 0.7482, MAE: 254.5916, RMSE: 303.4775
# [I 2025-01-30 16:35:07,523] Trial 8 finished with value: 0.7481852024348183 and parameters: {'n_estimators': 65, 'learning_rate': 0.02185426895994654, 'max_depth': 5, 'subsample': 0.8971973219069302, 'colsample_bytree': 0.5332980599256381, 'reg_alpha': 0.13051620583783546, 'reg_lambda': 0.10852739666835132, 'min_child_weight': 3, 'gamma': 1.6911811148556888}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 10 out of 20
# ✅ Trial 10 completed in 0.3s
#    MAPE: 0.1426, MAE: 72.4498, RMSE: 100.5895
# [I 2025-01-30 16:35:07,792] Trial 9 finished with value: 0.14260598154931528 and parameters: {'n_estimators': 89, 'learning_rate': 0.03207313692414264, 'max_depth': 7, 'subsample': 0.7029334571114878, 'colsample_bytree': 0.9324353406555717, 'reg_alpha': 7.94421857915387, 'reg_lambda': 8.577886077019478, 'min_child_weight': 1, 'gamma': 2.931777883455612}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 11 out of 20
# ✅ Trial 11 completed in 2.0s
#    MAPE: 0.0922, MAE: 65.7935, RMSE: 98.1140
# [I 2025-01-30 16:35:09,756] Trial 10 finished with value: 0.09220659776058386 and parameters: {'n_estimators': 491, 'learning_rate': 0.010363907569097382, 'max_depth': 11, 'subsample': 0.606472053729813, 'colsample_bytree': 0.7262283639363464, 'reg_alpha': 3.512571409969306, 'reg_lambda': 3.802766460831575, 'min_child_weight': 5, 'gamma': 0.040509452755887576}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 12 out of 20
# ✅ Trial 12 completed in 0.5s
#    MAPE: 0.0948, MAE: 66.0816, RMSE: 97.0932
# [I 2025-01-30 16:35:10,274] Trial 11 finished with value: 0.0947871963283165 and parameters: {'n_estimators': 392, 'learning_rate': 0.19407949635077282, 'max_depth': 3, 'subsample': 0.5253109115029142, 'colsample_bytree': 0.7683910697220139, 'reg_alpha': 8.87108842779488, 'reg_lambda': 9.096800876641415, 'min_child_weight': 4, 'gamma': 3.7220358884516784}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 13 out of 20
# ✅ Trial 13 completed in 0.6s
#    MAPE: 0.0945, MAE: 65.3183, RMSE: 95.7599
# [I 2025-01-30 16:35:10,844] Trial 12 finished with value: 0.09447465933154293 and parameters: {'n_estimators': 494, 'learning_rate': 0.12852226449954168, 'max_depth': 3, 'subsample': 0.5134191120779987, 'colsample_bytree': 0.7311659472376084, 'reg_alpha': 3.5230173227787622, 'reg_lambda': 3.5537958226575164, 'min_child_weight': 5, 'gamma': 0.7326701007039711}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 14 out of 20
# ✅ Trial 14 completed in 0.4s
#    MAPE: 0.0942, MAE: 66.5867, RMSE: 98.7735
# [I 2025-01-30 16:35:11,287] Trial 13 finished with value: 0.09416585711411775 and parameters: {'n_estimators': 368, 'learning_rate': 0.10956589640807217, 'max_depth': 9, 'subsample': 0.6232245944153506, 'colsample_bytree': 0.8308880321315848, 'reg_alpha': 4.329340013117335, 'reg_lambda': 0.47874692509570504, 'min_child_weight': 3, 'gamma': 1.7932543481148517}. Best is trial 3 with value: 0.09117442031139121.
# 🔄 Starting Trial 15 out of 20
# ✅ Trial 15 completed in 0.4s
#    MAPE: 0.0896, MAE: 66.0140, RMSE: 98.6386
# [I 2025-01-30 16:35:11,644] Trial 14 finished with value: 0.08956981639991841 and parameters: {'n_estimators': 206, 'learning_rate': 0.09039349965146042, 'max_depth': 5, 'subsample': 0.5936670113870827, 'colsample_bytree': 0.9939686359408468, 'reg_alpha': 2.225596452631923, 'reg_lambda': 4.181708490399382, 'min_child_weight': 6, 'gamma': 3.6920951631305043}. Best is trial 14 with value: 0.08956981639991841.
# 🔄 Starting Trial 16 out of 20
# ✅ Trial 16 completed in 0.6s
#    MAPE: 0.0975, MAE: 66.6622, RMSE: 97.7806
# [I 2025-01-30 16:35:12,291] Trial 15 finished with value: 0.09754338734319509 and parameters: {'n_estimators': 333, 'learning_rate': 0.08595113520516888, 'max_depth': 9, 'subsample': 0.6262782554040284, 'colsample_bytree': 0.6592718419042508, 'reg_alpha': 2.3368277814140574, 'reg_lambda': 2.487177491944709, 'min_child_weight': 7, 'gamma': 3.831378424600146}. Best is trial 14 with value: 0.08956981639991841.
# 🔄 Starting Trial 17 out of 20
# ✅ Trial 17 completed in 0.7s
#    MAPE: 0.1125, MAE: 68.2309, RMSE: 97.5958
# [I 2025-01-30 16:35:12,992] Trial 16 finished with value: 0.1124650457131562 and parameters: {'n_estimators': 221, 'learning_rate': 0.015956023704451497, 'max_depth': 6, 'subsample': 0.7387108772679398, 'colsample_bytree': 0.9919217240281992, 'reg_alpha': 1.9431909464970778, 'reg_lambda': 0.864374215714952, 'min_child_weight': 6, 'gamma': 3.555081685267566}. Best is trial 14 with value: 0.08956981639991841.
# 🔄 Starting Trial 18 out of 20
# ✅ Trial 18 completed in 1.4s
#    MAPE: 0.0897, MAE: 66.6911, RMSE: 100.7675
# [I 2025-01-30 16:35:14,426] Trial 17 finished with value: 0.0896742610977223 and parameters: {'n_estimators': 328, 'learning_rate': 0.03047722896297932, 'max_depth': 13, 'subsample': 0.5799730832828369, 'colsample_bytree': 0.9997387053436233, 'reg_alpha': 6.3891736286277485, 'reg_lambda': 5.699955970683833, 'min_child_weight': 6, 'gamma': 4.316340761974578}. Best is trial 14 with value: 0.08956981639991841.
# 🔄 Starting Trial 19 out of 20
# ✅ Trial 19 completed in 1.2s
#    MAPE: 0.0896, MAE: 66.3901, RMSE: 100.2231
# [I 2025-01-30 16:35:15,593] Trial 18 finished with value: 0.08962188406369644 and parameters: {'n_estimators': 312, 'learning_rate': 0.03246014215467758, 'max_depth': 13, 'subsample': 0.5777881269023633, 'colsample_bytree': 0.9970727123308067, 'reg_alpha': 0.6259466613114912, 'reg_lambda': 6.0438453227150175, 'min_child_weight': 6, 'gamma': 3.3265816149463805}. Best is trial 14 with value: 0.08956981639991841.
# 🔄 Starting Trial 20 out of 20
# ✅ Trial 20 completed in 0.7s
#    MAPE: 0.0997, MAE: 67.5469, RMSE: 99.1357
# [I 2025-01-30 16:35:16,355] Trial 19 finished with value: 0.09973470262667208 and parameters: {'n_estimators': 235, 'learning_rate': 0.08600400103975606, 'max_depth': 15, 'subsample': 0.6651674572076473, 'colsample_bytree': 0.8515680700820171, 'reg_alpha': 0.5571349010649754, 'reg_lambda': 0.7686985019666983, 'min_child_weight': 7, 'gamma': 3.1873356412662432}. Best is trial 14 with value: 0.08956981639991841.
# [I 2025-01-30 16:35:16,723] A new study created in memory with name: no-name-fac16239-36d0-4ce3-9198-eb1170803dd5
# 🏆 Best Trial Results:
# MAPE: 0.0896
# Best Parameters: {'n_estimators': 206, 'learning_rate': 0.09039349965146042, 'max_depth': 5, 'subsample': 0.5936670113870827, 'colsample_bytree': 0.9939686359408468, 'reg_alpha': 2.225596452631923, 'reg_lambda': 4.181708490399382, 'min_child_weight': 6, 'gamma': 3.6920951631305043, 'enable_categorical': True, 'device': 'cpu', 'tree_method': 'auto'}
#
# 📊 Results for Finland:
# Training samples: 32610
# Test samples: 5745
# Final MAPE: 0.0927
# Training time: 17.8s
#
# 🌍 Training model for Italy
# ==================================================
#   0%|          | 0/20 [00:00<?, ?it/s]
# 🔄 Starting Trial 1 out of 20
# ✅ Trial 1 completed in 1.2s
#    MAPE: 0.1091, MAE: 45.2541, RMSE: 64.2481
# [I 2025-01-30 16:35:17,927] Trial 0 finished with value: 0.10906520506146102 and parameters: {'n_estimators': 373, 'learning_rate': 0.040834948839449256, 'max_depth': 13, 'subsample': 0.7668403519358427, 'colsample_bytree': 0.5468468601204305, 'reg_alpha': 3.176576376345812, 'reg_lambda': 2.91647641685125, 'min_child_weight': 7, 'gamma': 4.03005220065191}. Best is trial 0 with value: 0.10906520506146102.
# 🔄 Starting Trial 2 out of 20
# ✅ Trial 2 completed in 0.8s
#    MAPE: 0.1150, MAE: 46.4377, RMSE: 66.3975
# [I 2025-01-30 16:35:18,757] Trial 1 finished with value: 0.11504352328473448 and parameters: {'n_estimators': 248, 'learning_rate': 0.02328012567919698, 'max_depth': 12, 'subsample': 0.9035618589322498, 'colsample_bytree': 0.6387898369394501, 'reg_alpha': 0.5238192179084964, 'reg_lambda': 5.560945917383307, 'min_child_weight': 2, 'gamma': 3.5205773758682524}. Best is trial 0 with value: 0.10906520506146102.
# 🔄 Starting Trial 3 out of 20
# ✅ Trial 3 completed in 0.9s
#    MAPE: 0.0844, MAE: 44.0164, RMSE: 66.8646
# [I 2025-01-30 16:35:19,657] Trial 2 finished with value: 0.08436380234091914 and parameters: {'n_estimators': 361, 'learning_rate': 0.031142731630368306, 'max_depth': 7, 'subsample': 0.5544478572382545, 'colsample_bytree': 0.9742033081784462, 'reg_alpha': 0.23688093223075543, 'reg_lambda': 6.2586206812974945, 'min_child_weight': 1, 'gamma': 3.1590820505021777}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 4 out of 20
# ✅ Trial 4 completed in 1.1s
#    MAPE: 0.0874, MAE: 43.9638, RMSE: 65.6889
# [I 2025-01-30 16:35:20,741] Trial 3 finished with value: 0.08740643920460894 and parameters: {'n_estimators': 306, 'learning_rate': 0.039896302284280226, 'max_depth': 17, 'subsample': 0.8398812715798698, 'colsample_bytree': 0.7439696249824088, 'reg_alpha': 0.7463525286606003, 'reg_lambda': 8.810990692734993, 'min_child_weight': 3, 'gamma': 0.9951803185112801}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 5 out of 20
# ✅ Trial 5 completed in 1.0s
#    MAPE: 0.0868, MAE: 45.4234, RMSE: 68.6507
# [I 2025-01-30 16:35:21,707] Trial 4 finished with value: 0.08684804473181756 and parameters: {'n_estimators': 409, 'learning_rate': 0.06913148198234684, 'max_depth': 15, 'subsample': 0.9348133493767744, 'colsample_bytree': 0.9405558619334309, 'reg_alpha': 0.28665143474081395, 'reg_lambda': 1.5356014398359448, 'min_child_weight': 6, 'gamma': 3.934660470606998}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 6 out of 20
# ✅ Trial 6 completed in 1.8s
#    MAPE: 0.1060, MAE: 46.1720, RMSE: 66.6524
# [I 2025-01-30 16:35:23,538] Trial 5 finished with value: 0.10603723241658242 and parameters: {'n_estimators': 391, 'learning_rate': 0.016548485244348144, 'max_depth': 14, 'subsample': 0.9203331801322485, 'colsample_bytree': 0.6199772752200197, 'reg_alpha': 0.1544150685625726, 'reg_lambda': 0.2105891871544282, 'min_child_weight': 2, 'gamma': 0.16871573451206323}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 7 out of 20
# ✅ Trial 7 completed in 0.1s
#    MAPE: 0.1024, MAE: 46.1056, RMSE: 66.2706
# [I 2025-01-30 16:35:23,676] Trial 6 finished with value: 0.10236515358082643 and parameters: {'n_estimators': 64, 'learning_rate': 0.19744844805603207, 'max_depth': 4, 'subsample': 0.7447239821833744, 'colsample_bytree': 0.6120331491439251, 'reg_alpha': 0.7231342422593765, 'reg_lambda': 1.9982414239569433, 'min_child_weight': 3, 'gamma': 1.7910005858197797}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 8 out of 20
# ✅ Trial 8 completed in 0.5s
#    MAPE: 0.0859, MAE: 44.2161, RMSE: 66.6294
# [I 2025-01-30 16:35:24,187] Trial 7 finished with value: 0.0858885031314921 and parameters: {'n_estimators': 415, 'learning_rate': 0.04312192435156368, 'max_depth': 5, 'subsample': 0.8580731907323694, 'colsample_bytree': 0.9269377003638185, 'reg_alpha': 0.37007336046415823, 'reg_lambda': 1.9717256508325713, 'min_child_weight': 2, 'gamma': 1.8521745671747962}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 9 out of 20
# ✅ Trial 9 completed in 1.0s
#    MAPE: 0.1578, MAE: 52.2947, RMSE: 71.9564
# [I 2025-01-30 16:35:25,154] Trial 8 finished with value: 0.15779253627838158 and parameters: {'n_estimators': 233, 'learning_rate': 0.011789879743793034, 'max_depth': 9, 'subsample': 0.5213071530925841, 'colsample_bytree': 0.8815807777155402, 'reg_alpha': 0.8021942613847157, 'reg_lambda': 0.4089744094176854, 'min_child_weight': 3, 'gamma': 1.5025786882661907}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 10 out of 20
# ✅ Trial 10 completed in 1.2s
#    MAPE: 0.0939, MAE: 45.7638, RMSE: 67.6320
# [I 2025-01-30 16:35:26,355] Trial 9 finished with value: 0.09391150988507853 and parameters: {'n_estimators': 310, 'learning_rate': 0.03779176457053023, 'max_depth': 10, 'subsample': 0.9134700949033256, 'colsample_bytree': 0.5773031477076648, 'reg_alpha': 0.5870908160676056, 'reg_lambda': 0.2607683815061466, 'min_child_weight': 4, 'gamma': 2.300239815838622}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 11 out of 20
# ✅ Trial 11 completed in 0.4s
#    MAPE: 0.0916, MAE: 46.3020, RMSE: 69.5256
# [I 2025-01-30 16:35:26,809] Trial 10 finished with value: 0.09161233540715405 and parameters: {'n_estimators': 493, 'learning_rate': 0.09281631590300977, 'max_depth': 7, 'subsample': 0.5211901019543351, 'colsample_bytree': 0.8218232542064354, 'reg_alpha': 3.420104483969784, 'reg_lambda': 0.6909876050597439, 'min_child_weight': 1, 'gamma': 4.760189029894325}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 12 out of 20
# ✅ Trial 12 completed in 0.8s
#    MAPE: 0.0965, MAE: 45.8859, RMSE: 66.2103
# [I 2025-01-30 16:35:27,607] Trial 11 finished with value: 0.09649181724042924 and parameters: {'n_estimators': 497, 'learning_rate': 0.02305973372951502, 'max_depth': 3, 'subsample': 0.6273476178319066, 'colsample_bytree': 0.9749454386694713, 'reg_alpha': 0.10201021492684754, 'reg_lambda': 4.022572454893005, 'min_child_weight': 1, 'gamma': 2.899175484844638}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 13 out of 20
# ✅ Trial 13 completed in 0.4s
#    MAPE: 0.0846, MAE: 43.9004, RMSE: 66.5219
# [I 2025-01-30 16:35:28,023] Trial 12 finished with value: 0.0845953313574044 and parameters: {'n_estimators': 144, 'learning_rate': 0.06941274708895272, 'max_depth': 6, 'subsample': 0.655127283567972, 'colsample_bytree': 0.999773927867367, 'reg_alpha': 0.2500716399222704, 'reg_lambda': 9.70479891350592, 'min_child_weight': 1, 'gamma': 2.904979359601814}. Best is trial 2 with value: 0.08436380234091914.
# 🔄 Starting Trial 14 out of 20
# ✅ Trial 14 completed in 0.4s
#    MAPE: 0.0844, MAE: 44.0618, RMSE: 66.9815
# [I 2025-01-30 16:35:28,441] Trial 13 finished with value: 0.08435253394858278 and parameters: {'n_estimators': 144, 'learning_rate': 0.08391450115544734, 'max_depth': 7, 'subsample': 0.6204110017627611, 'colsample_bytree': 0.9864058090663964, 'reg_alpha': 9.686922411831155, 'reg_lambda': 9.874567429043495, 'min_child_weight': 5, 'gamma': 2.9884836695563055}. Best is trial 13 with value: 0.08435253394858278.
# 🔄 Starting Trial 15 out of 20
# ✅ Trial 15 completed in 0.4s
#    MAPE: 0.0913, MAE: 45.6973, RMSE: 68.3854
# [I 2025-01-30 16:35:28,892] Trial 14 finished with value: 0.0912589642583738 and parameters: {'n_estimators': 129, 'learning_rate': 0.14279357661047218, 'max_depth': 7, 'subsample': 0.6130821654072889, 'colsample_bytree': 0.8324710254838742, 'reg_alpha': 9.553329717813748, 'reg_lambda': 0.1060263926332377, 'min_child_weight': 5, 'gamma': 3.194012423895874}. Best is trial 13 with value: 0.08435253394858278.
# 🔄 Starting Trial 16 out of 20
# ✅ Trial 16 completed in 0.6s
#    MAPE: 0.0884, MAE: 44.9782, RMSE: 67.5013
# [I 2025-01-30 16:35:29,458] Trial 15 finished with value: 0.08838194910777233 and parameters: {'n_estimators': 198, 'learning_rate': 0.09701488848990515, 'max_depth': 9, 'subsample': 0.6871689981535769, 'colsample_bytree': 0.735926799214648, 'reg_alpha': 2.4738725500373593, 'reg_lambda': 6.162314516920506, 'min_child_weight': 5, 'gamma': 4.98864517363352}. Best is trial 13 with value: 0.08435253394858278.
# 🔄 Starting Trial 17 out of 20
# ✅ Trial 17 completed in 0.3s
#    MAPE: 0.2895, MAE: 72.0100, RMSE: 91.8133
# [I 2025-01-30 16:35:29,757] Trial 16 finished with value: 0.2894833993154773 and parameters: {'n_estimators': 69, 'learning_rate': 0.025790330317793812, 'max_depth': 7, 'subsample': 0.5739717906520609, 'colsample_bytree': 0.8664749386898488, 'reg_alpha': 1.8179909449693124, 'reg_lambda': 0.8520176160827847, 'min_child_weight': 5, 'gamma': 2.328564137155526}. Best is trial 13 with value: 0.08435253394858278.
# 🔄 Starting Trial 18 out of 20
# ✅ Trial 18 completed in 0.6s
#    MAPE: 0.0853, MAE: 44.4294, RMSE: 67.5718
# [I 2025-01-30 16:35:30,407] Trial 17 finished with value: 0.08529478317696583 and parameters: {'n_estimators': 179, 'learning_rate': 0.059000763793731856, 'max_depth': 11, 'subsample': 0.5785611204000807, 'colsample_bytree': 0.9235805512764389, 'reg_alpha': 9.430951608941093, 'reg_lambda': 4.0141572307531925, 'min_child_weight': 7, 'gamma': 3.8670652067417826}. Best is trial 13 with value: 0.08435253394858278.
# 🔄 Starting Trial 19 out of 20
# ✅ Trial 19 completed in 0.4s
#    MAPE: 0.0878, MAE: 44.8765, RMSE: 67.4972
# [I 2025-01-30 16:35:30,807] Trial 18 finished with value: 0.08782365341755154 and parameters: {'n_estimators': 308, 'learning_rate': 0.11366831621744473, 'max_depth': 8, 'subsample': 0.7284663765687573, 'colsample_bytree': 0.7889503475188799, 'reg_alpha': 5.231228329658455, 'reg_lambda': 6.64625562776642, 'min_child_weight': 4, 'gamma': 4.541979814717687}. Best is trial 13 with value: 0.08435253394858278.
# 🔄 Starting Trial 20 out of 20
# ✅ Trial 20 completed in 1.0s
#    MAPE: 0.0879, MAE: 43.9220, RMSE: 65.4786
# [I 2025-01-30 16:35:31,805] Trial 19 finished with value: 0.08787053590231525 and parameters: {'n_estimators': 448, 'learning_rate': 0.028328405137477697, 'max_depth': 5, 'subsample': 0.5013599606457695, 'colsample_bytree': 0.6810556076498705, 'reg_alpha': 1.495523149806402, 'reg_lambda': 3.088811850306337, 'min_child_weight': 6, 'gamma': 2.6889578567988446}. Best is trial 13 with value: 0.08435253394858278.
# [I 2025-01-30 16:35:32,243] A new study created in memory with name: no-name-72296325-989d-4cf2-9e56-9ee263b46dd4
# 🏆 Best Trial Results:
# MAPE: 0.0844
# Best Parameters: {'n_estimators': 144, 'learning_rate': 0.08391450115544734, 'max_depth': 7, 'subsample': 0.6204110017627611, 'colsample_bytree': 0.9864058090663964, 'reg_alpha': 9.686922411831155, 'reg_lambda': 9.874567429043495, 'min_child_weight': 5, 'gamma': 2.9884836695563055, 'enable_categorical': True, 'device': 'cpu', 'tree_method': 'auto'}
#
# 📊 Results for Italy:
# Training samples: 32605
# Test samples: 5750
# Final MAPE: 0.0871
# Training time: 15.5s
#
# 🌍 Training model for Kenya
# ==================================================
#   0%|          | 0/20 [00:00<?, ?it/s]
# 🔄 Starting Trial 1 out of 20
# ✅ Trial 1 completed in 0.5s
#    MAPE: 5.8651, MAE: 93.8730, RMSE: 151.7847
# [I 2025-01-30 16:35:32,725] Trial 0 finished with value: 5.865053148261212 and parameters: {'n_estimators': 302, 'learning_rate': 0.11271190898222559, 'max_depth': 16, 'subsample': 0.7254187012982074, 'colsample_bytree': 0.5236300832836958, 'reg_alpha': 1.9991902818097396, 'reg_lambda': 0.18216199102068564, 'min_child_weight': 2, 'gamma': 1.6635074218365486}. Best is trial 0 with value: 5.865053148261212.
# 🔄 Starting Trial 2 out of 20
# ✅ Trial 2 completed in 0.8s
#    MAPE: 2.3676, MAE: 21.1038, RMSE: 62.7864
# [I 2025-01-30 16:35:33,559] Trial 1 finished with value: 2.3675835606415028 and parameters: {'n_estimators': 220, 'learning_rate': 0.014423617798988455, 'max_depth': 10, 'subsample': 0.9910195993219921, 'colsample_bytree': 0.896416545909304, 'reg_alpha': 5.052679864008598, 'reg_lambda': 2.38199243799127, 'min_child_weight': 4, 'gamma': 3.2510151891758294}. Best is trial 1 with value: 2.3675835606415028.
# 🔄 Starting Trial 3 out of 20
# ✅ Trial 3 completed in 2.8s
#    MAPE: 2.1666, MAE: 17.5220, RMSE: 71.5353
# [I 2025-01-30 16:35:36,393] Trial 2 finished with value: 2.1665743331371035 and parameters: {'n_estimators': 371, 'learning_rate': 0.09993158212088979, 'max_depth': 15, 'subsample': 0.9214792632226065, 'colsample_bytree': 0.8289872870876843, 'reg_alpha': 0.9743457865900854, 'reg_lambda': 4.0768188797547, 'min_child_weight': 2, 'gamma': 2.085980474881379}. Best is trial 2 with value: 2.1665743331371035.
# 🔄 Starting Trial 4 out of 20
# ✅ Trial 4 completed in 1.4s
#    MAPE: 2.0721, MAE: 15.7526, RMSE: 62.5654
# [I 2025-01-30 16:35:37,837] Trial 3 finished with value: 2.072111744529641 and parameters: {'n_estimators': 285, 'learning_rate': 0.017820086229290363, 'max_depth': 12, 'subsample': 0.925466290009493, 'colsample_bytree': 0.9558951108509658, 'reg_alpha': 4.376064275834168, 'reg_lambda': 1.7678420459407285, 'min_child_weight': 5, 'gamma': 3.760897306401338}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 5 out of 20
# ✅ Trial 5 completed in 0.5s
#    MAPE: 4.2657, MAE: 42.0482, RMSE: 80.3747
# [I 2025-01-30 16:35:38,373] Trial 4 finished with value: 4.265701949910903 and parameters: {'n_estimators': 295, 'learning_rate': 0.0619158466964057, 'max_depth': 3, 'subsample': 0.9065219877325528, 'colsample_bytree': 0.6420197354547731, 'reg_alpha': 4.1904430882087675, 'reg_lambda': 8.009464654747322, 'min_child_weight': 6, 'gamma': 1.0364120490640272}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 6 out of 20
# ✅ Trial 6 completed in 0.5s
#    MAPE: 2.2807, MAE: 18.2434, RMSE: 60.8986
# [I 2025-01-30 16:35:38,921] Trial 5 finished with value: 2.2806760077039026 and parameters: {'n_estimators': 127, 'learning_rate': 0.12547135798158685, 'max_depth': 10, 'subsample': 0.9471375960388562, 'colsample_bytree': 0.7857843529772124, 'reg_alpha': 0.7574420955360394, 'reg_lambda': 6.079643520059001, 'min_child_weight': 1, 'gamma': 0.6723074277529911}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 7 out of 20
# ✅ Trial 7 completed in 2.4s
#    MAPE: 3.1051, MAE: 28.8542, RMSE: 67.4626
# [I 2025-01-30 16:35:41,323] Trial 6 finished with value: 3.1050931247931097 and parameters: {'n_estimators': 491, 'learning_rate': 0.026185842514391558, 'max_depth': 13, 'subsample': 0.8710630961396459, 'colsample_bytree': 0.5973598091873329, 'reg_alpha': 0.6081123198032232, 'reg_lambda': 0.29783135759083273, 'min_child_weight': 6, 'gamma': 2.6362266804434737}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 8 out of 20
# ✅ Trial 8 completed in 0.7s
#    MAPE: 3.1723, MAE: 30.3340, RMSE: 69.1764
# [I 2025-01-30 16:35:41,993] Trial 7 finished with value: 3.1722651840874487 and parameters: {'n_estimators': 203, 'learning_rate': 0.022810101261109758, 'max_depth': 8, 'subsample': 0.8163213662291438, 'colsample_bytree': 0.8055914588544663, 'reg_alpha': 0.516634373119459, 'reg_lambda': 1.7779761956384523, 'min_child_weight': 3, 'gamma': 2.4012189609737584}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 9 out of 20
# ✅ Trial 9 completed in 0.3s
#    MAPE: 3.5253, MAE: 29.3895, RMSE: 69.7407
# [I 2025-01-30 16:35:42,301] Trial 8 finished with value: 3.5253194569252693 and parameters: {'n_estimators': 152, 'learning_rate': 0.08491040394836138, 'max_depth': 3, 'subsample': 0.9272532051096121, 'colsample_bytree': 0.8613791123604992, 'reg_alpha': 7.0085180774361096, 'reg_lambda': 0.1199313436080262, 'min_child_weight': 2, 'gamma': 3.500710881789444}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 10 out of 20
# ✅ Trial 10 completed in 0.3s
#    MAPE: 3.2371, MAE: 27.7018, RMSE: 64.8275
# [I 2025-01-30 16:35:42,573] Trial 9 finished with value: 3.237052834421291 and parameters: {'n_estimators': 150, 'learning_rate': 0.15276380244936, 'max_depth': 3, 'subsample': 0.8034993761082141, 'colsample_bytree': 0.8729881086257179, 'reg_alpha': 1.6235612338086896, 'reg_lambda': 2.1736679127568452, 'min_child_weight': 6, 'gamma': 2.0876974823481387}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 11 out of 20
# ✅ Trial 11 completed in 0.3s
#    MAPE: 4.9676, MAE: 87.5767, RMSE: 132.8849
# [I 2025-01-30 16:35:42,875] Trial 10 finished with value: 4.9675795516623085 and parameters: {'n_estimators': 52, 'learning_rate': 0.01090453822225284, 'max_depth': 13, 'subsample': 0.5640952287304282, 'colsample_bytree': 0.9986516611122618, 'reg_alpha': 0.1407035169404545, 'reg_lambda': 0.5794179026615384, 'min_child_weight': 7, 'gamma': 4.737606973817206}. Best is trial 3 with value: 2.072111744529641.
# 🔄 Starting Trial 12 out of 20
# ✅ Trial 12 completed in 2.1s
#    MAPE: 2.0676, MAE: 15.4851, RMSE: 65.8787
# [I 2025-01-30 16:35:44,967] Trial 11 finished with value: 2.0675573624072694 and parameters: {'n_estimators': 380, 'learning_rate': 0.044068247588234924, 'max_depth': 18, 'subsample': 0.7185505244778583, 'colsample_bytree': 0.9745583249522971, 'reg_alpha': 0.311184643905747, 'reg_lambda': 4.265056308846822, 'min_child_weight': 4, 'gamma': 4.364290243193903}. Best is trial 11 with value: 2.0675573624072694.
# 🔄 Starting Trial 13 out of 20
# ✅ Trial 13 completed in 1.9s
#    MAPE: 2.1065, MAE: 16.0020, RMSE: 66.6648
# [I 2025-01-30 16:35:46,906] Trial 12 finished with value: 2.106515534390608 and parameters: {'n_estimators': 397, 'learning_rate': 0.034193572988498275, 'max_depth': 17, 'subsample': 0.679381764110285, 'colsample_bytree': 0.9859266660263583, 'reg_alpha': 0.17436783247951154, 'reg_lambda': 0.9109976203965788, 'min_child_weight': 4, 'gamma': 4.801832333150462}. Best is trial 11 with value: 2.0675573624072694.
# 🔄 Starting Trial 14 out of 20
# ✅ Trial 14 completed in 1.9s
#    MAPE: 2.1091, MAE: 16.0397, RMSE: 65.1694
# [I 2025-01-30 16:35:48,808] Trial 13 finished with value: 2.109105799526955 and parameters: {'n_estimators': 348, 'learning_rate': 0.04892681537311563, 'max_depth': 18, 'subsample': 0.61780259512213, 'colsample_bytree': 0.9514972756345811, 'reg_alpha': 0.3097785655548706, 'reg_lambda': 3.8466911700284983, 'min_child_weight': 5, 'gamma': 4.009121079272971}. Best is trial 11 with value: 2.0675573624072694.
# 🔄 Starting Trial 15 out of 20
# ✅ Trial 15 completed in 1.4s
#    MAPE: 2.3211, MAE: 18.6170, RMSE: 60.3773
# [I 2025-01-30 16:35:50,183] Trial 14 finished with value: 2.3211031128595443 and parameters: {'n_estimators': 457, 'learning_rate': 0.0192417627575263, 'max_depth': 7, 'subsample': 0.6844226644963303, 'colsample_bytree': 0.7256429733568212, 'reg_alpha': 2.213546941058077, 'reg_lambda': 1.125529690055943, 'min_child_weight': 5, 'gamma': 4.165307508531575}. Best is trial 11 with value: 2.0675573624072694.
# 🔄 Starting Trial 16 out of 20
# ✅ Trial 16 completed in 1.6s
#    MAPE: 2.0653, MAE: 15.5939, RMSE: 63.7840
# [I 2025-01-30 16:35:51,739] Trial 15 finished with value: 2.0652798518461974 and parameters: {'n_estimators': 419, 'learning_rate': 0.03633939363480874, 'max_depth': 14, 'subsample': 0.7735960275057896, 'colsample_bytree': 0.9153504532572405, 'reg_alpha': 0.2878593562618538, 'reg_lambda': 3.628434363846283, 'min_child_weight': 5, 'gamma': 3.4266726558849214}. Best is trial 15 with value: 2.0652798518461974.
# 🔄 Starting Trial 17 out of 20
# ✅ Trial 17 completed in 2.8s
#    MAPE: 2.2800, MAE: 18.9600, RMSE: 66.0524
# [I 2025-01-30 16:35:54,576] Trial 16 finished with value: 2.2799711489436167 and parameters: {'n_estimators': 422, 'learning_rate': 0.03777391209349169, 'max_depth': 15, 'subsample': 0.7762791313219165, 'colsample_bytree': 0.7265752978738129, 'reg_alpha': 0.333014073000748, 'reg_lambda': 4.269636086974238, 'min_child_weight': 3, 'gamma': 3.003618495314515}. Best is trial 15 with value: 2.0652798518461974.
# 🔄 Starting Trial 18 out of 20
# ✅ Trial 18 completed in 2.5s
#    MAPE: 2.0317, MAE: 15.4084, RMSE: 64.5141
# [I 2025-01-30 16:35:57,073] Trial 17 finished with value: 2.0316762530965105 and parameters: {'n_estimators': 344, 'learning_rate': 0.0633574917225781, 'max_depth': 18, 'subsample': 0.5222389913084298, 'colsample_bytree': 0.9217196293315175, 'reg_alpha': 0.25489386984066514, 'reg_lambda': 7.335983282513131, 'min_child_weight': 3, 'gamma': 4.339669346756327}. Best is trial 17 with value: 2.0316762530965105.
# 🔄 Starting Trial 19 out of 20
# ✅ Trial 19 completed in 1.4s
#    MAPE: 2.0085, MAE: 15.1827, RMSE: 61.8930
# [I 2025-01-30 16:35:58,444] Trial 18 finished with value: 2.008508816821626 and parameters: {'n_estimators': 337, 'learning_rate': 0.06839743886316835, 'max_depth': 15, 'subsample': 0.5142914229082487, 'colsample_bytree': 0.9205177788310376, 'reg_alpha': 0.11802029567947248, 'reg_lambda': 9.529229623725607, 'min_child_weight': 3, 'gamma': 0.14415173940310755}. Best is trial 18 with value: 2.008508816821626.
# 🔄 Starting Trial 20 out of 20
# ✅ Trial 20 completed in 1.5s
#    MAPE: 2.6516, MAE: 24.6923, RMSE: 64.3093
# [I 2025-01-30 16:35:59,917] Trial 19 finished with value: 2.651594966803251 and parameters: {'n_estimators': 327, 'learning_rate': 0.19713268777951543, 'max_depth': 16, 'subsample': 0.5060260985251226, 'colsample_bytree': 0.6795045512065101, 'reg_alpha': 0.10411277350497315, 'reg_lambda': 9.235763096150718, 'min_child_weight': 3, 'gamma': 0.03744882304249231}. Best is trial 18 with value: 2.008508816821626.
# [I 2025-01-30 16:36:02,806] A new study created in memory with name: no-name-a852c13c-c6f7-43eb-b0d1-983d4f1c4044
# 🏆 Best Trial Results:
# MAPE: 2.0085
# Best Parameters: {'n_estimators': 337, 'learning_rate': 0.06839743886316835, 'max_depth': 15, 'subsample': 0.5142914229082487, 'colsample_bytree': 0.9205177788310376, 'reg_alpha': 0.11802029567947248, 'reg_lambda': 9.529229623725607, 'min_child_weight': 3, 'gamma': 0.14415173940310755, 'enable_categorical': True, 'device': 'cpu', 'tree_method': 'auto'}
#
# 📊 Results for Kenya:
# Training samples: 32595
# Test samples: 5760
# Final MAPE: 2.0905
# Training time: 30.6s
#
# 🌍 Training model for Norway
# ==================================================
#   0%|          | 0/20 [00:00<?, ?it/s]
# 🔄 Starting Trial 1 out of 20
# ✅ Trial 1 completed in 2.3s
#    MAPE: 0.1360, MAE: 135.4440, RMSE: 192.8875
# [I 2025-01-30 16:36:05,128] Trial 0 finished with value: 0.13602472150949416 and parameters: {'n_estimators': 185, 'learning_rate': 0.022855961238391287, 'max_depth': 18, 'subsample': 0.6014593020260105, 'colsample_bytree': 0.9129782653674798, 'reg_alpha': 1.4377589420036718, 'reg_lambda': 1.0443042073202553, 'min_child_weight': 2, 'gamma': 1.0264700280698846}. Best is trial 0 with value: 0.13602472150949416.
# 🔄 Starting Trial 2 out of 20
# ✅ Trial 2 completed in 1.4s
#    MAPE: 0.1169, MAE: 132.7593, RMSE: 187.1188
# [I 2025-01-30 16:36:06,495] Trial 1 finished with value: 0.11685945975040565 and parameters: {'n_estimators': 450, 'learning_rate': 0.013517938819948987, 'max_depth': 6, 'subsample': 0.6769715516673728, 'colsample_bytree': 0.7172893316322333, 'reg_alpha': 0.37015705819023975, 'reg_lambda': 7.673839644918192, 'min_child_weight': 6, 'gamma': 1.8604262904996183}. Best is trial 1 with value: 0.11685945975040565.
# 🔄 Starting Trial 3 out of 20
# ✅ Trial 3 completed in 0.3s
#    MAPE: 0.1181, MAE: 138.1107, RMSE: 200.6538
# [I 2025-01-30 16:36:06,779] Trial 2 finished with value: 0.11809572541791383 and parameters: {'n_estimators': 91, 'learning_rate': 0.17709030209637855, 'max_depth': 5, 'subsample': 0.6768161351543674, 'colsample_bytree': 0.972589827591747, 'reg_alpha': 0.9565919854834372, 'reg_lambda': 0.23614594447558462, 'min_child_weight': 1, 'gamma': 3.1803479691807697}. Best is trial 1 with value: 0.11685945975040565.
# 🔄 Starting Trial 4 out of 20
# ✅ Trial 4 completed in 0.8s
#    MAPE: 0.1217, MAE: 135.7612, RMSE: 198.1422
# [I 2025-01-30 16:36:07,561] Trial 3 finished with value: 0.12168254427213616 and parameters: {'n_estimators': 256, 'learning_rate': 0.1746516611599678, 'max_depth': 16, 'subsample': 0.7987793386223414, 'colsample_bytree': 0.8452337756284445, 'reg_alpha': 0.4035242331154856, 'reg_lambda': 8.466816455968782, 'min_child_weight': 1, 'gamma': 2.421142565847756}. Best is trial 1 with value: 0.11685945975040565.
# 🔄 Starting Trial 5 out of 20
# ✅ Trial 5 completed in 0.6s
#    MAPE: 0.1299, MAE: 139.4342, RMSE: 196.8278
# [I 2025-01-30 16:36:08,209] Trial 4 finished with value: 0.12985610460222688 and parameters: {'n_estimators': 244, 'learning_rate': 0.08176483632659524, 'max_depth': 8, 'subsample': 0.9878600898497387, 'colsample_bytree': 0.5514746490010297, 'reg_alpha': 0.16436640409130607, 'reg_lambda': 0.12354227886400507, 'min_child_weight': 1, 'gamma': 0.43193690213192415}. Best is trial 1 with value: 0.11685945975040565.
# 🔄 Starting Trial 6 out of 20
# ✅ Trial 6 completed in 0.6s
#    MAPE: 0.1260, MAE: 139.8074, RMSE: 203.9978
# [I 2025-01-30 16:36:08,844] Trial 5 finished with value: 0.12602104460586233 and parameters: {'n_estimators': 276, 'learning_rate': 0.15509371193770666, 'max_depth': 13, 'subsample': 0.9328346552506506, 'colsample_bytree': 0.6564636336107138, 'reg_alpha': 6.351836930528862, 'reg_lambda': 3.290425447212709, 'min_child_weight': 2, 'gamma': 2.050564373538032}. Best is trial 1 with value: 0.11685945975040565.
# 🔄 Starting Trial 7 out of 20
# ✅ Trial 7 completed in 1.1s
#    MAPE: 0.2309, MAE: 159.9206, RMSE: 195.0213
# [I 2025-01-30 16:36:09,975] Trial 6 finished with value: 0.23090211034743022 and parameters: {'n_estimators': 208, 'learning_rate': 0.01265551838197729, 'max_depth': 12, 'subsample': 0.9406942505441562, 'colsample_bytree': 0.9887740008709038, 'reg_alpha': 1.4524899291567572, 'reg_lambda': 1.0838183411654774, 'min_child_weight': 4, 'gamma': 0.013066921508102514}. Best is trial 1 with value: 0.11685945975040565.
# 🔄 Starting Trial 8 out of 20
# ✅ Trial 8 completed in 0.7s
#    MAPE: 0.2286, MAE: 198.3208, RMSE: 243.0260
# ...
# 🔄 Starting Trial 14 out of 20
# ✅ Trial 14 completed in 1.3s
#    MAPE: 0.1197, MAE: 135.0398, RMSE: 195.0065
# [I 2025-01-30 16:36:17,325] Trial 13 finished with value: 0.11974469945999652 and parameters: {'n_estimators': 418, 'learning_rate': 0.02659169488743549, 'max_depth': 10, 'subsample': 0.7459849353332566, 'colsample_bytree': 0.6095728629214504, 'reg_alpha': 0.197904995329971, 'reg_lambda': 3.2621819939988232, 'min_child_weight': 6, 'gamma': 3.495098399140908}. Best is trial 11 with value: 0.115728990399851.
# 🔄 Starting Trial 15 out of 20
# ✅ Trial 15 completed in 1.3s
#    MAPE: 0.1162, MAE: 132.6328, RMSE: 193.2064
# [I 2025-01-30 16:36:18,676] Trial 14 finished with value: 0.11624907303204798 and parameters: {'n_estimators': 385, 'learning_rate': 0.04005581040202341, 'max_depth': 13, 'subsample': 0.8299169064522783, 'colsample_bytree': 0.7731187676669362, 'reg_alpha': 0.10505045386417808, 'reg_lambda': 9.930064215552816, 'min_child_weight': 7, 'gamma': 3.4954432921707053}. Best is trial 11 with value: 0.115728990399851.
# 🔄 Starting Trial 16 out of 20
# ✅ Trial 16 completed in 1.6s
#    MAPE: 0.1185, MAE: 134.2891, RMSE: 192.7351
# [I 2025-01-30 16:36:20,251] Trial 15 finished with value: 0.11852057348493303 and parameters: {'n_estimators': 490, 'learning_rate': 0.019625007874650432, 'max_depth': 9, 'subsample': 0.7124650284699752, 'colsample_bytree': 0.7027481057615654, 'reg_alpha': 0.27357068341470975, 'reg_lambda': 5.120353149199685, 'min_child_weight': 5, 'gamma': 4.669497172517593}. Best is trial 11 with value: 0.115728990399851.
# 🔄 Starting Trial 17 out of 20
# ✅ Trial 17 completed in 1.6s
#    MAPE: 0.1178, MAE: 134.0572, RMSE: 198.0603
# [I 2025-01-30 16:36:21,810] Trial 16 finished with value: 0.11780387913826236 and parameters: {'n_estimators': 378, 'learning_rate': 0.0410617679794276, 'max_depth': 12, 'subsample': 0.6286937612365999, 'colsample_bytree': 0.8244599567353572, 'reg_alpha': 3.226352655200845, 'reg_lambda': 1.6543651822786611, 'min_child_weight': 4, 'gamma': 4.105294462957314}. Best is trial 11 with value: 0.115728990399851.
# 🔄 Starting Trial 18 out of 20
# ✅ Trial 18 completed in 1.7s
#    MAPE: 0.1281, MAE: 135.5914, RMSE: 192.3874
# [I 2025-01-30 16:36:23,510] Trial 17 finished with value: 0.12808021937480193 and parameters: {'n_estimators': 438, 'learning_rate': 0.017381514330979345, 'max_depth': 15, 'subsample': 0.8493565654875674, 'colsample_bytree': 0.6074706255561608, 'reg_alpha': 0.4912827350077276, 'reg_lambda': 4.927993703069739, 'min_child_weight': 6, 'gamma': 2.917219327415442}. Best is trial 11 with value: 0.115728990399851.
# 🔄 Starting Trial 19 out of 20
# ✅ Trial 19 completed in 0.8s
#    MAPE: 0.1181, MAE: 134.8422, RMSE: 194.8291
# [I 2025-01-30 16:36:24,292] Trial 18 finished with value: 0.11810964200560609 and parameters: {'n_estimators': 367, 'learning_rate': 0.05974242028629975, 'max_depth': 8, 'subsample': 0.7552461086158961, 'colsample_bytree': 0.6049675542434527, 'reg_alpha': 0.18931488251971626, 'reg_lambda': 2.420833699598668, 'min_child_weight': 5, 'gamma': 4.158773820345743}. Best is trial 11 with value: 0.115728990399851.
# 🔄 Starting Trial 20 out of 20
# ✅ Trial 20 completed in 0.3s
#    MAPE: 0.2364, MAE: 168.9468, RMSE: 199.5502
# [I 2025-01-30 16:36:24,593] Trial 19 finished with value: 0.2363923270583718 and parameters: {'n_estimators': 97, 'learning_rate': 0.029271025202983202, 'max_depth': 5, 'subsample': 0.5304105434338393, 'colsample_bytree': 0.8081999923049131, 'reg_alpha': 0.10283749689761632, 'reg_lambda': 0.5079084547978503, 'min_child_weight': 7, 'gamma': 4.988785056517518}. Best is trial 11 with value: 0.115728990399851.
# [I 2025-01-30 16:36:25,692] A new study created in memory with name: no-name-ff81ed96-4788-4cb1-956a-da6e2661a6e1
# 🏆 Best Trial Results:
# MAPE: 0.1157
# Best Parameters: {'n_estimators': 482, 'learning_rate': 0.0219996624434328, 'max_depth': 9, 'subsample': 0.7576232106530884, 'colsample_bytree': 0.6936335154713036, 'reg_alpha': 0.11824350959205644, 'reg_lambda': 9.402879805990972, 'min_child_weight': 7, 'gamma': 3.9786238157573868, 'enable_categorical': True, 'device': 'cpu', 'tree_method': 'auto'}
#
# 📊 Results for Norway:
# Training samples: 32595
# Test samples: 5760
# Final MAPE: 0.1158
# Training time: 22.9s
#
# 🌍 Training model for Singapore
# ==================================================
#   0%|          | 0/20 [00:00<?, ?it/s]
# 🔄 Starting Trial 1 out of 20
# ✅ Trial 1 completed in 1.1s
#    MAPE: 0.0938, MAE: 84.7305, RMSE: 125.0689
# [I 2025-01-30 16:36:26,762] Trial 0 finished with value: 0.09379330023953264 and parameters: {'n_estimators': 347, 'learning_rate': 0.05906260908030551, 'max_depth': 6, 'subsample': 0.5982821464023126, 'colsample_bytree': 0.6028490877609953, 'reg_alpha': 0.11089757662334422, 'reg_lambda': 2.2827388884268203, 'min_child_weight': 3, 'gamma': 0.6295150415820505}. Best is trial 0 with value: 0.09379330023953264.
# 🔄 Starting Trial 2 out of 20
# ✅ Trial 2 completed in 0.5s
#    MAPE: 0.0850, MAE: 79.8805, RMSE: 120.2206
# [I 2025-01-30 16:36:27,240] Trial 1 finished with value: 0.08498676821021622 and parameters: {'n_estimators': 159, 'learning_rate': 0.0696684891064068, 'max_depth': 4, 'subsample': 0.9051860105873033, 'colsample_bytree': 0.9227110009671095, 'reg_alpha': 0.5348972845071818, 'reg_lambda': 3.184326819742593, 'min_child_weight': 1, 'gamma': 0.03860664387659862}. Best is trial 1 with value: 0.08498676821021622.
# 🔄 Starting Trial 3 out of 20
# ✅ Trial 3 completed in 0.7s
#    MAPE: 0.0850, MAE: 82.6826, RMSE: 125.8492
# [I 2025-01-30 16:36:27,946] Trial 2 finished with value: 0.08496489438782374 and parameters: {'n_estimators': 453, 'learning_rate': 0.04455095890984158, 'max_depth': 9, 'subsample': 0.9318427403871253, 'colsample_bytree': 0.9299814471863659, 'reg_alpha': 1.2833180299993625, 'reg_lambda': 2.6597906175237367, 'min_child_weight': 7, 'gamma': 4.078938802588498}. Best is trial 2 with value: 0.08496489438782374.
# 🔄 Starting Trial 4 out of 20
# ✅ Trial 4 completed in 0.3s
#    MAPE: 0.0914, MAE: 83.7355, RMSE: 124.3995
# [I 2025-01-30 16:36:28,247] Trial 3 finished with value: 0.0913669716147471 and parameters: {'n_estimators': 264, 'learning_rate': 0.19829729593105014, 'max_depth': 7, 'subsample': 0.8073993272834659, 'colsample_bytree': 0.8445507450695331, 'reg_alpha': 5.784787561065263, 'reg_lambda': 1.1965399792607836, 'min_child_weight': 5, 'gamma': 3.031157841684497}. Best is trial 2 with value: 0.08496489438782374.
# 🔄 Starting Trial 5 out of 20
# ✅ Trial 5 completed in 0.6s
#    MAPE: 0.0845, MAE: 79.7719, RMSE: 121.5258
# [I 2025-01-30 16:36:28,810] Trial 4 finished with value: 0.0844643086370056 and parameters: {'n_estimators': 496, 'learning_rate': 0.02707509626003397, 'max_depth': 4, 'subsample': 0.5942151764830477, 'colsample_bytree': 0.9957029374512889, 'reg_alpha': 0.521460723504462, 'reg_lambda': 9.468305541853862, 'min_child_weight': 4, 'gamma': 1.5500664742331005}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 6 out of 20
# ✅ Trial 6 completed in 2.1s
#    MAPE: 0.1396, MAE: 100.7371, RMSE: 143.7966
# [I 2025-01-30 16:36:30,928] Trial 5 finished with value: 0.1396480945283509 and parameters: {'n_estimators': 385, 'learning_rate': 0.010750578975891894, 'max_depth': 16, 'subsample': 0.8070224545614386, 'colsample_bytree': 0.6974353745142647, 'reg_alpha': 0.8749018045238481, 'reg_lambda': 0.376611757101544, 'min_child_weight': 3, 'gamma': 0.587885822906028}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 7 out of 20
# ✅ Trial 7 completed in 0.9s
#    MAPE: 0.0863, MAE: 83.1746, RMSE: 126.2942
# [I 2025-01-30 16:36:31,841] Trial 6 finished with value: 0.08629498944903127 and parameters: {'n_estimators': 479, 'learning_rate': 0.0482526430146096, 'max_depth': 11, 'subsample': 0.732175207673669, 'colsample_bytree': 0.9198026310482627, 'reg_alpha': 1.2030668051064974, 'reg_lambda': 6.237211704820035, 'min_child_weight': 1, 'gamma': 2.761298554698448}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 8 out of 20
# ✅ Trial 8 completed in 0.8s
#    MAPE: 0.1065, MAE: 91.2174, RMSE: 131.0926
# [I 2025-01-30 16:36:32,597] Trial 7 finished with value: 0.1065140441652739 and parameters: {'n_estimators': 158, 'learning_rate': 0.13867244583705604, 'max_depth': 15, 'subsample': 0.9633151221911831, 'colsample_bytree': 0.6666954342638027, 'reg_alpha': 1.877127516012341, 'reg_lambda': 7.0615504677563665, 'min_child_weight': 2, 'gamma': 0.7425855571092821}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 9 out of 20
# ✅ Trial 9 completed in 2.6s
#    MAPE: 0.1001, MAE: 88.8206, RMSE: 129.9913
# [I 2025-01-30 16:36:35,200] Trial 8 finished with value: 0.1000624855576482 and parameters: {'n_estimators': 407, 'learning_rate': 0.0247620434350141, 'max_depth': 18, 'subsample': 0.694012602215847, 'colsample_bytree': 0.754953391793239, 'reg_alpha': 0.9323525402192068, 'reg_lambda': 0.16554213668013054, 'min_child_weight': 6, 'gamma': 0.5992602463322466}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 10 out of 20
# ✅ Trial 10 completed in 1.0s
#    MAPE: 0.0916, MAE: 84.3950, RMSE: 125.1006
# [I 2025-01-30 16:36:36,166] Trial 9 finished with value: 0.09163444606611432 and parameters: {'n_estimators': 116, 'learning_rate': 0.06191451771600316, 'max_depth': 16, 'subsample': 0.9563569690486764, 'colsample_bytree': 0.8031011105535235, 'reg_alpha': 1.7035854593743678, 'reg_lambda': 2.366713858159058, 'min_child_weight': 6, 'gamma': 2.3992167008558107}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 11 out of 20
# ✅ Trial 11 completed in 0.6s
#    MAPE: 0.2056, MAE: 143.1165, RMSE: 195.1226
# [I 2025-01-30 16:36:36,757] Trial 10 finished with value: 0.2055590061887875 and parameters: {'n_estimators': 264, 'learning_rate': 0.017584524204630216, 'max_depth': 3, 'subsample': 0.5004313237373528, 'colsample_bytree': 0.514891224225098, 'reg_alpha': 0.24465771028397187, 'reg_lambda': 0.5997450251286365, 'min_child_weight': 4, 'gamma': 1.763997646474756}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 12 out of 20
# ✅ Trial 12 completed in 1.1s
#    MAPE: 0.0854, MAE: 82.3694, RMSE: 125.4947
# [I 2025-01-30 16:36:37,825] Trial 11 finished with value: 0.08535548809395659 and parameters: {'n_estimators': 499, 'learning_rate': 0.028443888089433156, 'max_depth': 10, 'subsample': 0.6089887836598656, 'colsample_bytree': 0.9841093562039829, 'reg_alpha': 0.3996295507174663, 'reg_lambda': 9.963157064576086, 'min_child_weight': 5, 'gamma': 4.245092745755313}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 13 out of 20
# ✅ Trial 13 completed in 1.1s
#    MAPE: 0.0862, MAE: 83.2069, RMSE: 126.3551
# [I 2025-01-30 16:36:38,944] Trial 12 finished with value: 0.08622460595345813 and parameters: {'n_estimators': 439, 'learning_rate': 0.031349275002341304, 'max_depth': 10, 'subsample': 0.6479035302601335, 'colsample_bytree': 0.9980451729782308, 'reg_alpha': 3.929868789161805, 'reg_lambda': 4.325358562790041, 'min_child_weight': 7, 'gamma': 4.758299833910167}. Best is trial 4 with value: 0.0844643086370056.
# 🔄 Starting Trial 14 out of 20
# ✅ Trial 14 completed in 0.4s
#    MAPE: 0.0839, MAE: 80.6358, RMSE: 122.9914
# [I 2025-01-30 16:36:39,343] Trial 13 finished with value: 0.08385614805305465 and parameters: {'n_estimators': 352, 'learning_rate': 0.08991598128914878, 'max_depth': 7, 'subsample': 0.504480848761957, 'colsample_bytree': 0.9066144491058032, 'reg_alpha': 2.8750488153383498, 'reg_lambda': 1.1242070834477396, 'min_child_weight': 7, 'gamma': 3.819135590004596}. Best is trial 13 with value: 0.08385614805305465.
# 🔄 Starting Trial 15 out of 20
# ✅ Trial 15 completed in 0.4s
#    MAPE: 0.0879, MAE: 81.9305, RMSE: 123.0600
# [I 2025-01-30 16:36:39,693] Trial 14 finished with value: 0.08788107884005816 and parameters: {'n_estimators': 327, 'learning_rate': 0.10061891315996256, 'max_depth': 6, 'subsample': 0.5091239509264888, 'colsample_bytree': 0.8557962405214485, 'reg_alpha': 2.846874580513748, 'reg_lambda': 1.198988156950291, 'min_child_weight': 4, 'gamma': 3.5328487386539558}. Best is trial 13 with value: 0.08385614805305465.
# 🔄 Starting Trial 16 out of 20
# ✅ Trial 16 completed in 0.4s
#    MAPE: 0.0871, MAE: 80.1503, RMSE: 120.4944
# [I 2025-01-30 16:36:40,110] Trial 15 finished with value: 0.08712487763649504 and parameters: {'n_estimators': 327, 'learning_rate': 0.1023384578755722, 'max_depth': 4, 'subsample': 0.557263945155718, 'colsample_bytree': 0.8563254917588291, 'reg_alpha': 0.19631635253291863, 'reg_lambda': 0.23939413681206953, 'min_child_weight': 5, 'gamma': 1.5754463583066582}. Best is trial 13 with value: 0.08385614805305465.
# 🔄 Starting Trial 17 out of 20
# ✅ Trial 17 completed in 0.8s
#    MAPE: 0.1069, MAE: 84.2451, RMSE: 125.7169
# [I 2025-01-30 16:36:40,930] Trial 16 finished with value: 0.10691475837686554 and parameters: {'n_estimators': 213, 'learning_rate': 0.015461075234856288, 'max_depth': 8, 'subsample': 0.5599060615994235, 'colsample_bytree': 0.9526269237693219, 'reg_alpha': 8.8290458493076, 'reg_lambda': 0.1062121347081257, 'min_child_weight': 3, 'gamma': 1.7510014253600628}. Best is trial 13 with value: 0.08385614805305465.
# 🔄 Starting Trial 18 out of 20
# ✅ Trial 18 completed in 1.3s
#    MAPE: 0.0893, MAE: 85.4731, RMSE: 128.3697
# [I 2025-01-30 16:36:42,268] Trial 17 finished with value: 0.08933969485927948 and parameters: {'n_estimators': 381, 'learning_rate': 0.03655002992982911, 'max_depth': 13, 'subsample': 0.6632852331431827, 'colsample_bytree': 0.8900485338921464, 'reg_alpha': 0.5643696257208932, 'reg_lambda': 0.9291078683726287, 'min_child_weight': 6, 'gamma': 3.5231299879504463}. Best is trial 13 with value: 0.08385614805305465.
# 🔄 Starting Trial 19 out of 20
# ✅ Trial 19 completed in 1.1s
#    MAPE: 0.0862, MAE: 80.9687, RMSE: 121.7665
# [I 2025-01-30 16:36:43,341] Trial 18 finished with value: 0.08617046169815823 and parameters: {'n_estimators': 434, 'learning_rate': 0.021806765600407, 'max_depth': 5, 'subsample': 0.5474055564020207, 'colsample_bytree': 0.7738465026045915, 'reg_alpha': 3.064413551974888, 'reg_lambda': 0.46928437396847283, 'min_child_weight': 2, 'gamma': 2.2888587762357395}. Best is trial 13 with value: 0.08385614805305465.
# 🔄 Starting Trial 20 out of 20
# ✅ Trial 20 completed in 0.2s
#    MAPE: 0.0916, MAE: 83.3046, RMSE: 124.7874
# [I 2025-01-30 16:36:43,577] Trial 19 finished with value: 0.09164447637839127 and parameters: {'n_estimators': 74, 'learning_rate': 0.088937955816182, 'max_depth': 3, 'subsample': 0.6010035743220304, 'colsample_bytree': 0.976502153262411, 'reg_alpha': 0.30166972966934635, 'reg_lambda': 1.5994970908382717, 'min_child_weight': 4, 'gamma': 4.810666106717558}. Best is trial 13 with value: 0.08385614805305465.
#
# 🏆 Best Trial Results:
# MAPE: 0.0839
# Best Parameters: {'n_estimators': 352, 'learning_rate': 0.08991598128914878, 'max_depth': 7, 'subsample': 0.504480848761957, 'colsample_bytree': 0.9066144491058032, 'reg_alpha': 2.8750488153383498, 'reg_lambda': 1.1242070834477396, 'min_child_weight': 7, 'gamma': 3.819135590004596, 'enable_categorical': True, 'device': 'cpu', 'tree_method': 'auto'}
#
# 📊 Results for Singapore:
# Training samples: 32595
# Test samples: 5760
# Final MAPE: 0.1094
# Training time: 18.9s
#
# ⏱️ Total training time: 131.7s
#
# 📑 Overall Summary:
# ==================================================
#      Country      MAPE  Training Samples  Test Samples  Training Time (s)
# 0     Canada  0.132703             32610          5745          26.108863
# 1    Finland  0.092732             32610          5745          17.770232
# 2      Italy  0.087103             32605          5750          15.518747
# 3      Kenya  2.090534             32595          5760          30.567101
# 4     Norway  0.115763             32595          5760          22.865295
# 5  Singapore  0.109449             32595          5760          18.851979

# %%
country_models
# Out:
# {'Canada': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.9844347586090221, device='cpu',
#                early_stopping_rounds=None, enable_categorical=True,
#                eval_metric=None, feature_types=None, gamma=4.1264740724932345,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.19925144741463305,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=15, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=199, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#   'study': <optuna.study.study.Study at 0x1f9ddfcd8d0>,
#   'mape': 0.13270264595981837,
#   'n_train_samples': 32610,
#   'n_test_samples': 5745,
#   'best_parameters': {'n_estimators': 199,
#    'learning_rate': 0.19925144741463305,
#    'max_depth': 15,
#    'subsample': 0.7796923094040221,
#    'colsample_bytree': 0.9844347586090221,
#    'reg_alpha': 0.1096781616965365,
#    'reg_lambda': 1.1262048708328567,
#    'min_child_weight': 2,
#    'gamma': 4.1264740724932345},
#   'training_time': 26.10886287689209},
#  'Finland': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.9939686359408468, device='cpu',
#                early_stopping_rounds=None, enable_categorical=True,
#                eval_metric=None, feature_types=None, gamma=3.6920951631305043,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.09039349965146042,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=5, max_leaves=None,
#                min_child_weight=6, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=206, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#   'study': <optuna.study.study.Study at 0x1f9e03d8430>,
#   'mape': 0.09273189623332824,
#   'n_train_samples': 32610,
#   'n_test_samples': 5745,
#   'best_parameters': {'n_estimators': 206,
#    'learning_rate': 0.09039349965146042,
#    'max_depth': 5,
#    'subsample': 0.5936670113870827,
#    'colsample_bytree': 0.9939686359408468,
#    'reg_alpha': 2.225596452631923,
#    'reg_lambda': 4.181708490399382,
#    'min_child_weight': 6,
#    'gamma': 3.6920951631305043},
#   'training_time': 17.7702317237854},
#  'Italy': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.9864058090663964, device='cpu',
#                early_stopping_rounds=None, enable_categorical=True,
#                eval_metric=None, feature_types=None, gamma=2.9884836695563055,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.08391450115544734,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=7, max_leaves=None,
#                min_child_weight=5, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=144, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#   'study': <optuna.study.study.Study at 0x1f9e0408e20>,
#   'mape': 0.08710255399811628,
#   'n_train_samples': 32605,
#   'n_test_samples': 5750,
#   'best_parameters': {'n_estimators': 144,
#    'learning_rate': 0.08391450115544734,
#    'max_depth': 7,
#    'subsample': 0.6204110017627611,
#    'colsample_bytree': 0.9864058090663964,
#    'reg_alpha': 9.686922411831155,
#    'reg_lambda': 9.874567429043495,
#    'min_child_weight': 5,
#    'gamma': 2.9884836695563055},
#   'training_time': 15.518747329711914},
#  'Kenya': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.9205177788310376, device='cpu',
#                early_stopping_rounds=None, enable_categorical=True,
#                eval_metric=None, feature_types=None, gamma=0.14415173940310755,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.06839743886316835,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=15, max_leaves=None,
#                min_child_weight=3, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=337, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#   'study': <optuna.study.study.Study at 0x1f9e04079a0>,
#   'mape': 2.0905339203837467,
#   'n_train_samples': 32595,
#   'n_test_samples': 5760,
#   'best_parameters': {'n_estimators': 337,
#    'learning_rate': 0.06839743886316835,
#    'max_depth': 15,
#    'subsample': 0.5142914229082487,
#    'colsample_bytree': 0.9205177788310376,
#    'reg_alpha': 0.11802029567947248,
#    'reg_lambda': 9.529229623725607,
#    'min_child_weight': 3,
#    'gamma': 0.14415173940310755},
#   'training_time': 30.56710124015808},
#  'Norway': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.6936335154713036, device='cpu',
#                early_stopping_rounds=None, enable_categorical=True,
#                eval_metric=None, feature_types=None, gamma=3.9786238157573868,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.0219996624434328,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=9, max_leaves=None,
#                min_child_weight=7, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=482, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#   'study': <optuna.study.study.Study at 0x1f9e03d9d20>,
#   'mape': 0.1157629810919822,
#   'n_train_samples': 32595,
#   'n_test_samples': 5760,
#   'best_parameters': {'n_estimators': 482,
#    'learning_rate': 0.0219996624434328,
#    'max_depth': 9,
#    'subsample': 0.7576232106530884,
#    'colsample_bytree': 0.6936335154713036,
#    'reg_alpha': 0.11824350959205644,
#    'reg_lambda': 9.402879805990972,
#    'min_child_weight': 7,
#    'gamma': 3.9786238157573868},
#   'training_time': 22.86529517173767},
#  'Singapore': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.9066144491058032, device='cpu',
#                early_stopping_rounds=None, enable_categorical=True,
#                eval_metric=None, feature_types=None, gamma=3.819135590004596,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.08991598128914878,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=7, max_leaves=None,
#                min_child_weight=7, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=352, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#   'study': <optuna.study.study.Study at 0x1f9e0447fa0>,
#   'mape': 0.10944880857409302,
#   'n_train_samples': 32595,
#   'n_test_samples': 5760,
#   'best_parameters': {'n_estimators': 352,
#    'learning_rate': 0.08991598128914878,
#    'max_depth': 7,
#    'subsample': 0.504480848761957,
#    'colsample_bytree': 0.9066144491058032,
#    'reg_alpha': 2.8750488153383498,
#    'reg_lambda': 1.1242070834477396,
#    'min_child_weight': 7,
#    'gamma': 3.819135590004596},
#   'training_time': 18.85197949409485}}

# %%
X_train
# Out:
#        country              store             product is_holiday  day_of_year  \
# id
# 0       Canada  Discount Stickers   Holographic Goose       True            1
# 1       Canada  Discount Stickers              Kaggle       True            1
# 2       Canada  Discount Stickers        Kaggle Tiers       True            1
# 3       Canada  Discount Stickers            Kerneler       True            1
# 4       Canada  Discount Stickers  Kerneler Dark Mode       True            1
# ...        ...                ...                 ...        ...          ...
# 195605   Italy  Stickers for Less   Holographic Goose      False          348
# 195606   Italy  Stickers for Less              Kaggle      False          348
# 195607   Italy  Stickers for Less        Kaggle Tiers      False          348
# 195608   Italy  Stickers for Less            Kerneler      False          348
# 195609   Italy  Stickers for Less  Kerneler Dark Mode      False          348
#
#         month  year
# id
# 0           1  2010
# 1           1  2010
# 2           1  2010
# 3           1  2010
# 4           1  2010
# ...       ...   ...
# 195605     12  2015
# 195606     12  2015
# 195607     12  2015
# 195608     12  2015
# 195609     12  2015
#
# [195610 rows x 7 columns]

# %%
predictions_df
# Out:
#           on     num_sold
# 0          0   752.895813
# 1          1   659.886780
# 2          2   559.243164
# 3          3   302.295563
# 4          4   331.575073
# ...      ...          ...
# 98545  98545   428.819061
# 98546  98546  2209.399414
# 98547  98547  1989.598511
# 98548  98548  1101.572266
# 98549  98549  1322.858276
#
# [98550 rows x 2 columns]

# %%
blind
# Out:
#           country                 store             product is_holiday  \
# id
# 230130     Canada     Discount Stickers   Holographic Goose       True
# 230131     Canada     Discount Stickers              Kaggle       True
# 230132     Canada     Discount Stickers        Kaggle Tiers       True
# 230133     Canada     Discount Stickers            Kerneler       True
# 230134     Canada     Discount Stickers  Kerneler Dark Mode       True
# ...           ...                   ...                 ...        ...
# 328675  Singapore  Premium Sticker Mart   Holographic Goose      False
# 328676  Singapore  Premium Sticker Mart              Kaggle      False
# 328677  Singapore  Premium Sticker Mart        Kaggle Tiers      False
# 328678  Singapore  Premium Sticker Mart            Kerneler      False
# 328679  Singapore  Premium Sticker Mart  Kerneler Dark Mode      False
#
#         day_of_year  month  year     on
# id
# 230130            1      1  2017      1
# 230131            1      1  2017      2
# 230132            1      1  2017      3
# 230133            1      1  2017      4
# 230134            1      1  2017      5
# ...             ...    ...   ...    ...
# 328675          365     12  2019  98546
# 328676          365     12  2019  98547
# 328677          365     12  2019  98548
# 328678          365     12  2019  98549
# 328679          365     12  2019  98550
#
# [98550 rows x 8 columns]

# %%
predictions_df = pd.DataFrame({"num_sold": predictions})
predictions_df = predictions_df.reset_index().rename(columns={"index": "on"})


blind['on'] = range(1, len(blind) + 1)

submissions = blind.merge(predictions_df, on='on', how='left')
submissions = submissions[["num_sold", "id"]]
submissions = submissions.set_index("id")

# %%
submissions.to_csv("submission.csv")
# Out:
# c:\Users\Leo\.pyenv\pyenv-win-venv\envs\venv_kaggle\lib\site-packages\pandas\core\indexes\base.py:7834: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
